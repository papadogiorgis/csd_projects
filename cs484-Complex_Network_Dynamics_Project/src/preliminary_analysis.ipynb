# %% [markdown]
# # Preliminary Analysis
#
# **Author:** Papadakis Georgios (4975)<br>
# **Course:** CS-484 Complex Network Dynamics<br>
# **Supervisor:** Dr. Lionakis Panagiotis<br>
# **Project Phase:** A<br>
# **File:** src/preliminary_analysis.ipynb

# %%
from clean import *
from preliminary_analysis_functions import *
# Out:
# Plots will be saved to: c:\Users\papad\Desktop\ΣΧΟΛΗ\484\project484_4975\plots

# %%
print("Starting Preliminary Analysis Script")
#load and clean datasets
df_btc, df_ep = clean_data()
print("Data Cleaning complete.")
# Out:
# Starting Preliminary Analysis Script
# Loading data from: c:\Users\papad\Desktop\ΣΧΟΛΗ\484\project484_4975\datasets\bitcoinotc.csv
# --- Bitcoin OTC Data Loaded Successfully ---
# Bitcoin OTC | Number of lines before cleaning: 35592
# Bitcoin OTC | Number of lines after cleaning: 35592
#
# ...
#
# Loading data from: c:\Users\papad\Desktop\ΣΧΟΛΗ\484\project484_4975\datasets\epinions.csv
# --- Epinions Data Loaded Successfully ---
# Epinions | Number of lines before cleaning: 841372
# Epinions | 573 self-loops detected!
# Epinions | Number of lines after cleaning: 840799
#
# ...
#
# Data Cleaning complete.

# %%
#create graphs
G_btc, G_ep = create_graphs(df_btc, df_ep)
# Out:
# --- Creating NetworkX DiGraphs ---
# Adding 'normalized_rating' to Bitcoin OTC Graph...
# Bitcoin OTC Graph created
# Epinions Graph created
#
# ...

# %%
#basic statistics
calculate_basic_stats(G_btc, "Bitcoin_OTC")
calculate_basic_stats(G_ep, "Epinions")
# Out:
# --- Basic Statistics for Bitcoin_OTC ---
# Total Nodes: 5881
# Total Edges: 35592
# Density: 0.001029
# --- Basic Statistics for Epinions ---
# Total Nodes: 131580
# Total Edges: 840799
# Density: 0.000049

# %%
#Rating Distributions
#i used the dataframes because they have the ratings
plot_rating_distribution(df_btc, "Bitcoin_OTC")
plot_rating_distribution(df_ep, "Epinions")
# Out:
# --- Bitcoin_OTC Positive/Negative Statistics ---
# Total Ratings: 35592
# Positive: 32029 (89.989%)
# Negative: 3563 (10.011%)
#
# ...
#
# Plotting Detailed Rating Distribution for Bitcoin_OTC...
# Plot saved as Bitcoin_OTC_rating_distribution.png
# Plotting Normalized Rating Distribution for Bitcoin_OTC...
# Normalized plot saved as c:\Users\papad\Desktop\ΣΧΟΛΗ\484\project484_4975\plots\Bitcoin_OTC_rating_distribution_normalized.png
# --- Epinions Positive/Negative Statistics ---
# Total Ratings: 840799
# Positive: 717129 (85.291%)
# Negative: 123670 (14.709%)
#
# ...
#
# Plotting Detailed Rating Distribution for Epinions...
# Plot saved as Epinions_rating_distribution.png

# %%
#Degree Distributions (Log-Log)
plot_degree_distribution(G_btc, "Bitcoin_OTC")
plot_degree_distribution(G_ep, "Epinions")
# Out:
# Plotting Degree Distribution for Bitcoin_OTC...
# Plot saved as Bitcoin_OTC_degree_distribution.png
# Plotting Degree Distribution for Epinions...
# Plot saved as Epinions_degree_distribution.png

# %%
#Weighted Degree Distributions (Linear)
plot_weighted_degree_distribution(G_btc, "Bitcoin_OTC")
plot_weighted_degree_distribution(G_ep, "Epinions")
# Out:
# Plotting Weighted Degree Distribution for Bitcoin_OTC (Real Weights)...
# Plot saved as Bitcoin_OTC_weighted_degree_distribution.png
# Plotting Normalized Weighted Degree Distribution for Bitcoin_OTC...
# Normalized plot saved as Bitcoin_OTC_weighted_degree_distribution_normalized.png
# Plotting Weighted Degree Distribution for Epinions (Real Weights)...
# Plot saved as Epinions_weighted_degree_distribution.png
